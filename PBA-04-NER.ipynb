# %% [markdown]
# # PROYEK PBA - Named Entity Recognition (NER)

# %% [markdown]
# KELOMPOK 4
# - 12S18020 - Dita L. Sastri Sihombing
# - 12S18029 - Estomihi Rascana Sirait
# - 12S18061 - Angela Friscilia Simamora

# %% [markdown]
# IMPLEMENTASI POSTAGGING PADA SINGGALANG TEXT

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
from nltk import word_tokenize
from nltk.tag import CRFTagger

# %% [markdown]
# # LOAD DATASET

# %%
tsv_file = open('C:/Users/Lenovo/data/SINGGALANG.tsv')

# %%
import csv

# %%
with open("C:/Users/Lenovo/data/SINGGALANG.tsv") as file:
    tsv_file = csv.reader(file, delimiter="\t")
    for line in tsv_file:
        print(line)
# Out:
# ['Ia', 'O']
# ['menjabat', 'O']
# ['sebagai', 'O']
# ['Presiden', 'O']
# ['ketiga', 'O']
# ['Mesir', 'Place']
# ['pada', 'O']
# ['periode', 'O']
# ['15', 'O']
# ['Oktober', 'O']
# ['1970', 'O']
# ['hingga', 'O']
# ['terbunuhnya', 'O']
# ['pada', 'O']
# ['6', 'O']
# ['Oktober', 'O']
# ['1981', 'O']
# ['.', 'O']
# []
# ['Oleh', 'O']
# ['dunia', 'O']
# ['Barat', 'O']
# ['ia', 'O']
# ['dianggap', 'O']
# ['sebagai', 'O']
# ['orang', 'O']
# ['yang', 'O']
# ['sangat', 'O']
# ['berpengaruh', 'O']
# ['di', 'O']
# ['Mesir', 'Place']
# ['dan', 'O']
# ['di', 'O']
# ['Timur', 'O']
# ['Tengah', 'O']
# ['dalam', 'O']
# ['sejarah', 'O']
# ['modern', 'O']
# ['.', 'O']
# []
# ['Sadat', 'Person']
# ['dilahirkan', 'O']
# ['di', 'O']
# ['Mit', 'O']
# ['Abu', 'O']
# ['Al-Kum', 'O']
# [',', 'O']
# ['Al-Minufiyah', 'O']
# [',', 'O']
# ['Mesir', 'Place']
# [',', 'O']
# ['dalam', 'O']
# ['sebuah', 'O']
# ['keluarga', 'O']
# ['Mesir-sudan', 'O']
# ['yang', 'O']
# ['miskin', 'O']
# [',', 'O']
# ['dengan', 'O']
# ...

# %% [markdown]
# # PREPROCESSING

# %%
def preprocessing(text):
    case_folded = text.lower()
    tokenized = word_tokenize(case_folded)
    return tokenized

# %% [markdown]
# Pengenalan entitas bernama (NER)
# Mengidentifikasi dan mengklasifikasikan entitas bernama ke dalam kategori yang telah ditentukan sebelumnya
# Kategori termasuk orang, organisasi, negara, dll.

# %%
with open("C:/Users/Lenovo/data/SINGGALANG.tsv") as file:
    tsv_file = csv.reader(file, delimiter="\t")
    for line in tsv_file:
        print(line)
# Out:
# ['Ia', 'O']
# ['menjabat', 'O']
# ['sebagai', 'O']
# ['Presiden', 'O']
# ['ketiga', 'O']
# ['Mesir', 'Place']
# ['pada', 'O']
# ['periode', 'O']
# ['15', 'O']
# ['Oktober', 'O']
# ['1970', 'O']
# ['hingga', 'O']
# ['terbunuhnya', 'O']
# ['pada', 'O']
# ['6', 'O']
# ['Oktober', 'O']
# ['1981', 'O']
# ['.', 'O']
# []
# ['Oleh', 'O']
# ['dunia', 'O']
# ['Barat', 'O']
# ['ia', 'O']
# ['dianggap', 'O']
# ['sebagai', 'O']
# ['orang', 'O']
# ['yang', 'O']
# ['sangat', 'O']
# ['berpengaruh', 'O']
# ['di', 'O']
# ['Mesir', 'Place']
# ['dan', 'O']
# ['di', 'O']
# ['Timur', 'O']
# ['Tengah', 'O']
# ['dalam', 'O']
# ['sejarah', 'O']
# ['modern', 'O']
# ['.', 'O']
# []
# ['Sadat', 'Person']
# ['dilahirkan', 'O']
# ['di', 'O']
# ['Mit', 'O']
# ['Abu', 'O']
# ['Al-Kum', 'O']
# [',', 'O']
# ['Al-Minufiyah', 'O']
# [',', 'O']
# ['Mesir', 'Place']
# [',', 'O']
# ['dalam', 'O']
# ['sebuah', 'O']
# ['keluarga', 'O']
# ['Mesir-sudan', 'O']
# ['yang', 'O']
# ['miskin', 'O']
# [',', 'O']
# ['dengan', 'O']
# ...

# %% [markdown]
# Dari output tersebut kita memperhatikan jika tag place untuk kata yang mendefenisikan tempat, dan O untuk kata text lainnya.
# semua data dengan label 'O' memuat informasi kata kerja, tanggal, kata penghubung dsb. Sehingga 'POSTAGGING' akan dilakukan untuk memberikan tag kelas tertentu pada kata kata tersebut

# %% [markdown]
# # POSTAGGING

# %%
ct = CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11412/3511618428.py in <module>
# ----> 1 ct = CRFTagger()
#       2 ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')
#
# ~\anaconda3\lib\site-packages\nltk\tag\crf.py in __init__(self, feature_func, verbose, training_opt)
#      80
#      81         self._model_file = ""
# ---> 82         self._tagger = pycrfsuite.Tagger()
#      83
#      84         if feature_func is None:
#
# NameError: name 'pycrfsuite' is not defined

# %%
pos_singgalang = ct.tag_sents(df.preprocessed_singgalang)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11412/1299855554.py in <module>
# ----> 1 pos_singgalang = ct.tag_sents(df.preprocessed_singgalang)
#
# NameError: name 'ct' is not defined
